# %% [markdown]
# # Case_17_Assistencia_Tecnica_de_Eletronicos - laboratório pandas
# Execute o pipeline e explore a camada tratada.

# %%
from pathlib import Path
import pandas as pd
BASE=Path.cwd().parent if Path.cwd().name=='src' else Path.cwd()
inventario=pd.read_csv(BASE/'documentacao_pipeline/inventario_pipeline.csv')
inventario

# %%
df=pd.read_csv(BASE/'dados_tratados_pipeline/tipos_equipamento.csv')
df.info()
df.head()
