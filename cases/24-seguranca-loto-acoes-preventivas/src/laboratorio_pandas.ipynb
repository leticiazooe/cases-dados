# %% [markdown]
# # Segurança Industrial, LOTO e Ações Preventivas - laboratório pandas

# %%
from pathlib import Path
import pandas as pd
BASE=Path.cwd().parent if Path.cwd().name=='src' else Path.cwd()

# %%
df=pd.read_csv(BASE/'dados_tratados_pipeline/acoes.csv')
df.info()
df.head()
