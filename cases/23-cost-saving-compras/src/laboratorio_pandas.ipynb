# %% [markdown]
# # Cost Saving e Performance de Compras - laboratório pandas

# %%
from pathlib import Path
import pandas as pd
BASE=Path.cwd().parent if Path.cwd().name=='src' else Path.cwd()

# %%
df=pd.read_csv(BASE/'dados_tratados_pipeline/pedidos_compra.csv')
df.info()
df.head()
