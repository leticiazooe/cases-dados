# %% [markdown]
# # Laboratório Pandas - Calibracao e Gestao Metrologica\nUse este notebook para explorar os CSVs tratados.

# %%
from pathlib import Path\nimport pandas as pd\nROOT = Path.cwd().parent\nsorted((ROOT / "dados_tratados_pipeline").glob("*.csv"))
